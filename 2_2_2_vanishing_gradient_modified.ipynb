# %% [markdown]
# # 準備

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('../common')
sys.path.append('../data')

# %% [markdown]
# # vanishing gradient modified

# %% [markdown]
# ## multi layer network class

# %%
import numpy as np
#from common import layers
import layers
from collections import OrderedDict
#from common import functions
import functions
#from data.mnist import load_mnist
from mnist import load_mnist
import matplotlib.pyplot as plt


class MultiLayerNet:
    '''
    input_size: 入力層のノード数
    hidden_size_list: 隠れ層のノード数のリスト
    output_size: 出力層のノード数
    activation: 活性化関数
    weight_init_std: 重みの初期化方法
    '''
    def __init__(self, input_size, hidden_size_list, output_size, activation='relu', weight_init_std='relu'):
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size_list = hidden_size_list
        self.hidden_layer_num = len(hidden_size_list)
        self.params = {}

        # 重みの初期化
        self.__init_weight(weight_init_std)

        # レイヤの生成, sigmoidとreluのみ扱う
        activation_layer = {'sigmoid': layers.Sigmoid, 'relu': layers.Relu}
        self.layers = OrderedDict() # 追加した順番に格納
        for idx in range(1, self.hidden_layer_num+1):
            self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])
            self.layers['Activation_function' + str(idx)] = activation_layer[activation]()

        idx = self.hidden_layer_num + 1
        self.layers['Affine' + str(idx)] = layers.Affine(self.params['W' + str(idx)], self.params['b' + str(idx)])

        self.last_layer = layers.SoftmaxWithLoss()

    def __init_weight(self, weight_init_std):
        all_size_list = [self.input_size] + self.hidden_size_list + [self.output_size]
        for idx in range(1, len(all_size_list)):
            scale = weight_init_std
            if str(weight_init_std).lower() in ('relu', 'he'):
                scale = np.sqrt(2.0 / all_size_list[idx - 1])
            elif str(weight_init_std).lower() in ('sigmoid', 'xavier'):
                scale = np.sqrt(1.0 / all_size_list[idx - 1])

            self.params['W' + str(idx)] = scale * np.random.randn(all_size_list[idx-1], all_size_list[idx])
            self.params['b' + str(idx)] = np.zeros(all_size_list[idx])

    def predict(self, x):
        for layer in self.layers.values():
            x = layer.forward(x)

        return x

    def loss(self, x, d):
        y = self.predict(x)

        weight_decay = 0
        for idx in range(1, self.hidden_layer_num + 2):
            W = self.params['W' + str(idx)]

        return self.last_layer.forward(y, d) + weight_decay

    def accuracy(self, x, d):
        y = self.predict(x)
        y = np.argmax(y, axis=1)
        if d.ndim != 1 : d = np.argmax(d, axis=1)

        accuracy = np.sum(y == d) / float(x.shape[0])
        return accuracy

    def gradient(self, x, d):
        # forward
        self.loss(x, d)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        layers = list(self.layers.values())
        layers.reverse()
        for layer in layers:
            dout = layer.backward(dout)

        # 設定
        grad = {}
        for idx in range(1, self.hidden_layer_num+2):
            grad['W' + str(idx)] = self.layers['Affine' + str(idx)].dW
            grad['b' + str(idx)] = self.layers['Affine' + str(idx)].db

        return grad

# %% [markdown]
# ## vanishing sample
# ## sigmoid - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[50, 100], output_size=10, activation='sigmoid', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.12
#                 : 10. 正答率(テスト) = 0.1032
# Generation: 20. 正答率(トレーニング) = 0.08
#                 : 20. 正答率(テスト) = 0.1032
# Generation: 30. 正答率(トレーニング) = 0.12
#                 : 30. 正答率(テスト) = 0.1032
# Generation: 40. 正答率(トレーニング) = 0.09
#                 : 40. 正答率(テスト) = 0.1135
# Generation: 50. 正答率(トレーニング) = 0.12
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.1
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.1
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.15
#                 : 80. 正答率(テスト) = 0.1028
# Generation: 90. 正答率(トレーニング) = 0.2
#                 : 90. 正答率(テスト) = 0.1032
# Generation: 100. 正答率(トレーニング) = 0.11
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.14
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.12
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.08
#                 : 130. 正答率(テスト) = 0.0974
# Generation: 140. 正答率(トレーニング) = 0.16
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.12
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.12
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.1
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.08
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.15
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.15
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.14
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.11
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.23
#                 : 230. 正答率(テスト) = 0.1028
# Generation: 240. 正答率(トレーニング) = 0.15
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.14
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.14
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.15
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.08
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.11
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.13
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.09
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.14
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.13
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.08
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.16
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.09
#                 : 360. 正答率(テスト) = 0.1032
# Generation: 370. 正答率(トレーニング) = 0.1
#                 : 370. 正答率(テスト) = 0.1028
# Generation: 380. 正答率(トレーニング) = 0.07
#                 : 380. 正答率(テスト) = 0.1028
# Generation: 390. 正答率(トレーニング) = 0.07
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.08
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.12
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.13
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.14
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.09
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.07
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.1
#                 : 460. 正答率(テスト) = 0.1028
# Generation: 470. 正答率(トレーニング) = 0.12
#                 : 470. 正答率(テスト) = 0.1028
# Generation: 480. 正答率(トレーニング) = 0.13
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.13
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.09
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.11
#                 : 510. 正答率(テスト) = 0.1028
# Generation: 520. 正答率(トレーニング) = 0.1
#                 : 520. 正答率(テスト) = 0.1135
# Generation: 530. 正答率(トレーニング) = 0.11
#                 : 530. 正答率(テスト) = 0.1135
# Generation: 540. 正答率(トレーニング) = 0.19
#                 : 540. 正答率(テスト) = 0.1135
# Generation: 550. 正答率(トレーニング) = 0.14
#                 : 550. 正答率(テスト) = 0.1135
# Generation: 560. 正答率(トレーニング) = 0.12
#                 : 560. 正答率(テスト) = 0.1032
# Generation: 570. 正答率(トレーニング) = 0.1
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.11
#                 : 580. 正答率(テスト) = 0.1135
# Generation: 590. 正答率(トレーニング) = 0.05
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.16
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.09
#                 : 610. 正答率(テスト) = 0.1135
# Generation: 620. 正答率(トレーニング) = 0.13
#                 : 620. 正答率(テスト) = 0.1032
# Generation: 630. 正答率(トレーニング) = 0.09
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.13
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.15
#                 : 650. 正答率(テスト) = 0.101
# Generation: 660. 正答率(トレーニング) = 0.15
#                 : 660. 正答率(テスト) = 0.1032
# Generation: 670. 正答率(トレーニング) = 0.08
#                 : 670. 正答率(テスト) = 0.1135
# Generation: 680. 正答率(トレーニング) = 0.13
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.15
#                 : 690. 正答率(テスト) = 0.101
# Generation: 700. 正答率(トレーニング) = 0.08
#                 : 700. 正答率(テスト) = 0.1032
# Generation: 710. 正答率(トレーニング) = 0.11
#                 : 710. 正答率(テスト) = 0.101
# Generation: 720. 正答率(トレーニング) = 0.12
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.1
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.13
#                 : 740. 正答率(テスト) = 0.1028
# Generation: 750. 正答率(トレーニング) = 0.1
#                 : 750. 正答率(テスト) = 0.1135
# Generation: 760. 正答率(トレーニング) = 0.11
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.11
#                 : 770. 正答率(テスト) = 0.1028
# Generation: 780. 正答率(トレーニング) = 0.06
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.08
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.11
#                 : 800. 正答率(テスト) = 0.1135
# Generation: 810. 正答率(トレーニング) = 0.1
#                 : 810. 正答率(テスト) = 0.1028
# Generation: 820. 正答率(トレーニング) = 0.08
#                 : 820. 正答率(テスト) = 0.1028
# Generation: 830. 正答率(トレーニング) = 0.11
#                 : 830. 正答率(テスト) = 0.1028
# Generation: 840. 正答率(トレーニング) = 0.08
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.06
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.1
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.1
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.09
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.08
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.12
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.15
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.13
#                 : 920. 正答率(テスト) = 0.1028
# Generation: 930. 正答率(トレーニング) = 0.07
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.13
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.19
#                 : 950. 正答率(テスト) = 0.101
# Generation: 960. 正答率(トレーニング) = 0.11
#                 : 960. 正答率(テスト) = 0.101
# Generation: 970. 正答率(トレーニング) = 0.14
#                 : 970. 正答率(テスト) = 0.101
# Generation: 980. 正答率(トレーニング) = 0.14
#                 : 980. 正答率(テスト) = 0.101
# Generation: 990. 正答率(トレーニング) = 0.08
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.12
#                 : 1000. 正答率(テスト) = 0.101
# Generation: 1010. 正答率(トレーニング) = 0.16
#                 : 1010. 正答率(テスト) = 0.101
# Generation: 1020. 正答率(トレーニング) = 0.09
#                 : 1020. 正答率(テスト) = 0.1135
# Generation: 1030. 正答率(トレーニング) = 0.12
#                 : 1030. 正答率(テスト) = 0.1135
# Generation: 1040. 正答率(トレーニング) = 0.11
#                 : 1040. 正答率(テスト) = 0.1135
# Generation: 1050. 正答率(トレーニング) = 0.09
#                 : 1050. 正答率(テスト) = 0.1135
# Generation: 1060. 正答率(トレーニング) = 0.16
#                 : 1060. 正答率(テスト) = 0.1135
# Generation: 1070. 正答率(トレーニング) = 0.12
#                 : 1070. 正答率(テスト) = 0.1135
# Generation: 1080. 正答率(トレーニング) = 0.11
#                 : 1080. 正答率(テスト) = 0.1135
# Generation: 1090. 正答率(トレーニング) = 0.09
#                 : 1090. 正答率(テスト) = 0.1135
# Generation: 1100. 正答率(トレーニング) = 0.13
#                 : 1100. 正答率(テスト) = 0.1135
# Generation: 1110. 正答率(トレーニング) = 0.06
#                 : 1110. 正答率(テスト) = 0.1135
# Generation: 1120. 正答率(トレーニング) = 0.13
#                 : 1120. 正答率(テスト) = 0.1135
# Generation: 1130. 正答率(トレーニング) = 0.11
#                 : 1130. 正答率(テスト) = 0.1135
# Generation: 1140. 正答率(トレーニング) = 0.09
#                 : 1140. 正答率(テスト) = 0.1135
# Generation: 1150. 正答率(トレーニング) = 0.08
#                 : 1150. 正答率(テスト) = 0.1009
# Generation: 1160. 正答率(トレーニング) = 0.1
#                 : 1160. 正答率(テスト) = 0.1135
# Generation: 1170. 正答率(トレーニング) = 0.11
#                 : 1170. 正答率(テスト) = 0.1135
# Generation: 1180. 正答率(トレーニング) = 0.1
#                 : 1180. 正答率(テスト) = 0.1009
# Generation: 1190. 正答率(トレーニング) = 0.1
#                 : 1190. 正答率(テスト) = 0.1135
# Generation: 1200. 正答率(トレーニング) = 0.11
#                 : 1200. 正答率(テスト) = 0.1032
# Generation: 1210. 正答率(トレーニング) = 0.14
#                 : 1210. 正答率(テスト) = 0.101
# Generation: 1220. 正答率(トレーニング) = 0.14
#                 : 1220. 正答率(テスト) = 0.101
# Generation: 1230. 正答率(トレーニング) = 0.17
#                 : 1230. 正答率(テスト) = 0.1135
# Generation: 1240. 正答率(トレーニング) = 0.1
#                 : 1240. 正答率(テスト) = 0.1135
# Generation: 1250. 正答率(トレーニング) = 0.15
#                 : 1250. 正答率(テスト) = 0.1135
# Generation: 1260. 正答率(トレーニング) = 0.12
#                 : 1260. 正答率(テスト) = 0.1135
# Generation: 1270. 正答率(トレーニング) = 0.1
#                 : 1270. 正答率(テスト) = 0.1135
# Generation: 1280. 正答率(トレーニング) = 0.14
#                 : 1280. 正答率(テスト) = 0.1135
# Generation: 1290. 正答率(トレーニング) = 0.1
#                 : 1290. 正答率(テスト) = 0.1135
# Generation: 1300. 正答率(トレーニング) = 0.08
#                 : 1300. 正答率(テスト) = 0.1135
# Generation: 1310. 正答率(トレーニング) = 0.14
#                 : 1310. 正答率(テスト) = 0.1135
# Generation: 1320. 正答率(トレーニング) = 0.05
#                 : 1320. 正答率(テスト) = 0.1135
# Generation: 1330. 正答率(トレーニング) = 0.1
#                 : 1330. 正答率(テスト) = 0.1135
# Generation: 1340. 正答率(トレーニング) = 0.13
#                 : 1340. 正答率(テスト) = 0.1028
# Generation: 1350. 正答率(トレーニング) = 0.17
#                 : 1350. 正答率(テスト) = 0.1135
# Generation: 1360. 正答率(トレーニング) = 0.06
#                 : 1360. 正答率(テスト) = 0.1135
# Generation: 1370. 正答率(トレーニング) = 0.09
#                 : 1370. 正答率(テスト) = 0.1028
# Generation: 1380. 正答率(トレーニング) = 0.06
#                 : 1380. 正答率(テスト) = 0.101
# Generation: 1390. 正答率(トレーニング) = 0.11
#                 : 1390. 正答率(テスト) = 0.1028
# Generation: 1400. 正答率(トレーニング) = 0.08
#                 : 1400. 正答率(テスト) = 0.0958
# Generation: 1410. 正答率(トレーニング) = 0.11
#                 : 1410. 正答率(テスト) = 0.1135
# Generation: 1420. 正答率(トレーニング) = 0.1
#                 : 1420. 正答率(テスト) = 0.1135
# Generation: 1430. 正答率(トレーニング) = 0.09
#                 : 1430. 正答率(テスト) = 0.0958
# Generation: 1440. 正答率(トレーニング) = 0.17
#                 : 1440. 正答率(テスト) = 0.0958
# Generation: 1450. 正答率(トレーニング) = 0.11
#                 : 1450. 正答率(テスト) = 0.1135
# Generation: 1460. 正答率(トレーニング) = 0.16
#                 : 1460. 正答率(テスト) = 0.101
# Generation: 1470. 正答率(トレーニング) = 0.11
#                 : 1470. 正答率(テスト) = 0.1135
# Generation: 1480. 正答率(トレーニング) = 0.12
#                 : 1480. 正答率(テスト) = 0.1135
# Generation: 1490. 正答率(トレーニング) = 0.07
#                 : 1490. 正答率(テスト) = 0.1135
# Generation: 1500. 正答率(トレーニング) = 0.09
#                 : 1500. 正答率(テスト) = 0.1135
# Generation: 1510. 正答率(トレーニング) = 0.08
#                 : 1510. 正答率(テスト) = 0.1135
# Generation: 1520. 正答率(トレーニング) = 0.15
#                 : 1520. 正答率(テスト) = 0.1135
# Generation: 1530. 正答率(トレーニング) = 0.16
#                 : 1530. 正答率(テスト) = 0.1135
# Generation: 1540. 正答率(トレーニング) = 0.14
#                 : 1540. 正答率(テスト) = 0.1135
# Generation: 1550. 正答率(トレーニング) = 0.1
#                 : 1550. 正答率(テスト) = 0.1135
# Generation: 1560. 正答率(トレーニング) = 0.12
#                 : 1560. 正答率(テスト) = 0.1135
# Generation: 1570. 正答率(トレーニング) = 0.12
#                 : 1570. 正答率(テスト) = 0.1135
# Generation: 1580. 正答率(トレーニング) = 0.05
#                 : 1580. 正答率(テスト) = 0.1028
# Generation: 1590. 正答率(トレーニング) = 0.05
#                 : 1590. 正答率(テスト) = 0.098
# Generation: 1600. 正答率(トレーニング) = 0.07
#                 : 1600. 正答率(テスト) = 0.1028
# Generation: 1610. 正答率(トレーニング) = 0.14
#                 : 1610. 正答率(テスト) = 0.1028
# Generation: 1620. 正答率(トレーニング) = 0.16
#                 : 1620. 正答率(テスト) = 0.1135
# Generation: 1630. 正答率(トレーニング) = 0.14
#                 : 1630. 正答率(テスト) = 0.1135
# Generation: 1640. 正答率(トレーニング) = 0.15
#                 : 1640. 正答率(テスト) = 0.1135
# Generation: 1650. 正答率(トレーニング) = 0.1
#                 : 1650. 正答率(テスト) = 0.1135
# Generation: 1660. 正答率(トレーニング) = 0.13
#                 : 1660. 正答率(テスト) = 0.1135
# Generation: 1670. 正答率(トレーニング) = 0.09
#                 : 1670. 正答率(テスト) = 0.0958
# Generation: 1680. 正答率(トレーニング) = 0.09
#                 : 1680. 正答率(テスト) = 0.0958
# Generation: 1690. 正答率(トレーニング) = 0.15
#                 : 1690. 正答率(テスト) = 0.101
# Generation: 1700. 正答率(トレーニング) = 0.2
#                 : 1700. 正答率(テスト) = 0.0958
# Generation: 1710. 正答率(トレーニング) = 0.07
#                 : 1710. 正答率(テスト) = 0.101
# Generation: 1720. 正答率(トレーニング) = 0.12
#                 : 1720. 正答率(テスト) = 0.1135
# Generation: 1730. 正答率(トレーニング) = 0.09
#                 : 1730. 正答率(テスト) = 0.1135
# Generation: 1740. 正答率(トレーニング) = 0.13
#                 : 1740. 正答率(テスト) = 0.1135
# Generation: 1750. 正答率(トレーニング) = 0.1
#                 : 1750. 正答率(テスト) = 0.1135
# Generation: 1760. 正答率(トレーニング) = 0.1
#                 : 1760. 正答率(テスト) = 0.1135
# Generation: 1770. 正答率(トレーニング) = 0.13
#                 : 1770. 正答率(テスト) = 0.1135
# Generation: 1780. 正答率(トレーニング) = 0.18
#                 : 1780. 正答率(テスト) = 0.1135
# Generation: 1790. 正答率(トレーニング) = 0.09
#                 : 1790. 正答率(テスト) = 0.1135
# Generation: 1800. 正答率(トレーニング) = 0.14
#                 : 1800. 正答率(テスト) = 0.1135
# Generation: 1810. 正答率(トレーニング) = 0.14
#                 : 1810. 正答率(テスト) = 0.098
# Generation: 1820. 正答率(トレーニング) = 0.14
#                 : 1820. 正答率(テスト) = 0.1135
# Generation: 1830. 正答率(トレーニング) = 0.11
#                 : 1830. 正答率(テスト) = 0.1135
# Generation: 1840. 正答率(トレーニング) = 0.15
#                 : 1840. 正答率(テスト) = 0.1028
# Generation: 1850. 正答率(トレーニング) = 0.14
#                 : 1850. 正答率(テスト) = 0.1135
# Generation: 1860. 正答率(トレーニング) = 0.13
#                 : 1860. 正答率(テスト) = 0.1135
# Generation: 1870. 正答率(トレーニング) = 0.14
#                 : 1870. 正答率(テスト) = 0.1135
# Generation: 1880. 正答率(トレーニング) = 0.08
#                 : 1880. 正答率(テスト) = 0.1135
# Generation: 1890. 正答率(トレーニング) = 0.08
#                 : 1890. 正答率(テスト) = 0.1135
# Generation: 1900. 正答率(トレーニング) = 0.14
#                 : 1900. 正答率(テスト) = 0.1135
# Generation: 1910. 正答率(トレーニング) = 0.17
#                 : 1910. 正答率(テスト) = 0.1135
# Generation: 1920. 正答率(トレーニング) = 0.12
#                 : 1920. 正答率(テスト) = 0.1135
# Generation: 1930. 正答率(トレーニング) = 0.11
#                 : 1930. 正答率(テスト) = 0.1135
# Generation: 1940. 正答率(トレーニング) = 0.14
#                 : 1940. 正答率(テスト) = 0.1135
# Generation: 1950. 正答率(トレーニング) = 0.08
#                 : 1950. 正答率(テスト) = 0.1135
# Generation: 1960. 正答率(トレーニング) = 0.19
#                 : 1960. 正答率(テスト) = 0.1009
# Generation: 1970. 正答率(トレーニング) = 0.07
#                 : 1970. 正答率(テスト) = 0.1135
# Generation: 1980. 正答率(トレーニング) = 0.08
#                 : 1980. 正答率(テスト) = 0.1135
# Generation: 1990. 正答率(トレーニング) = 0.1
#                 : 1990. 正答率(テスト) = 0.1028
# Generation: 2000. 正答率(トレーニング) = 0.09
#                 : 2000. 正答率(テスト) = 0.098

# %% [markdown]
# ## ReLU - gauss

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='relu', weight_init_std=0.01)

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.15
#                 : 10. 正答率(テスト) = 0.1028
# Generation: 20. 正答率(トレーニング) = 0.1
#                 : 20. 正答率(テスト) = 0.1028
# Generation: 30. 正答率(トレーニング) = 0.1
#                 : 30. 正答率(テスト) = 0.1028
# Generation: 40. 正答率(トレーニング) = 0.09
#                 : 40. 正答率(テスト) = 0.1028
# Generation: 50. 正答率(トレーニング) = 0.1
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.13
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.08
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.13
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.1
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.09
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.09
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.08
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.09
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.14
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.08
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.17
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.06
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.2
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.12
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.08
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.14
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.06
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.16
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.03
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.1
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.11
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.16
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.14
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.14
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.06
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.08
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.12
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.09
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.15
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.05
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.09
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.11
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.09
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.14
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.15
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.08
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.13
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.13
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.15
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.12
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.15
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.13
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.16
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.09
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.17
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.16
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.15
#                 : 520. 正答率(テスト) = 0.1267
# Generation: 530. 正答率(トレーニング) = 0.25
#                 : 530. 正答率(テスト) = 0.2015
# Generation: 540. 正答率(トレーニング) = 0.2
#                 : 540. 正答率(テスト) = 0.2091
# Generation: 550. 正答率(トレーニング) = 0.23
#                 : 550. 正答率(テスト) = 0.2104
# Generation: 560. 正答率(トレーニング) = 0.28
#                 : 560. 正答率(テスト) = 0.2109
# Generation: 570. 正答率(トレーニング) = 0.17
#                 : 570. 正答率(テスト) = 0.2108
# Generation: 580. 正答率(トレーニング) = 0.16
#                 : 580. 正答率(テスト) = 0.2117
# Generation: 590. 正答率(トレーニング) = 0.2
#                 : 590. 正答率(テスト) = 0.2195
# Generation: 600. 正答率(トレーニング) = 0.18
#                 : 600. 正答率(テスト) = 0.2309
# Generation: 610. 正答率(トレーニング) = 0.22
#                 : 610. 正答率(テスト) = 0.2772
# Generation: 620. 正答率(トレーニング) = 0.28
#                 : 620. 正答率(テスト) = 0.3139
# Generation: 630. 正答率(トレーニング) = 0.27
#                 : 630. 正答率(テスト) = 0.3338
# Generation: 640. 正答率(トレーニング) = 0.39
#                 : 640. 正答率(テスト) = 0.3493
# Generation: 650. 正答率(トレーニング) = 0.44
#                 : 650. 正答率(テスト) = 0.4133
# Generation: 660. 正答率(トレーニング) = 0.48
#                 : 660. 正答率(テスト) = 0.4251
# Generation: 670. 正答率(トレーニング) = 0.52
#                 : 670. 正答率(テスト) = 0.4728
# Generation: 680. 正答率(トレーニング) = 0.6
#                 : 680. 正答率(テスト) = 0.5271
# Generation: 690. 正答率(トレーニング) = 0.66
#                 : 690. 正答率(テスト) = 0.5598
# Generation: 700. 正答率(トレーニング) = 0.6
#                 : 700. 正答率(テスト) = 0.5326
# Generation: 710. 正答率(トレーニング) = 0.65
#                 : 710. 正答率(テスト) = 0.5885
# Generation: 720. 正答率(トレーニング) = 0.7
#                 : 720. 正答率(テスト) = 0.6322
# Generation: 730. 正答率(トレーニング) = 0.69
#                 : 730. 正答率(テスト) = 0.6331
# Generation: 740. 正答率(トレーニング) = 0.7
#                 : 740. 正答率(テスト) = 0.6884
# Generation: 750. 正答率(トレーニング) = 0.67
#                 : 750. 正答率(テスト) = 0.6869
# Generation: 760. 正答率(トレーニング) = 0.75
#                 : 760. 正答率(テスト) = 0.6795
# Generation: 770. 正答率(トレーニング) = 0.85
#                 : 770. 正答率(テスト) = 0.7424
# Generation: 780. 正答率(トレーニング) = 0.77
#                 : 780. 正答率(テスト) = 0.7545
# Generation: 790. 正答率(トレーニング) = 0.73
#                 : 790. 正答率(テスト) = 0.7243
# Generation: 800. 正答率(トレーニング) = 0.84
#                 : 800. 正答率(テスト) = 0.7317
# Generation: 810. 正答率(トレーニング) = 0.82
#                 : 810. 正答率(テスト) = 0.7712
# Generation: 820. 正答率(トレーニング) = 0.85
#                 : 820. 正答率(テスト) = 0.7682
# Generation: 830. 正答率(トレーニング) = 0.82
#                 : 830. 正答率(テスト) = 0.768
# Generation: 840. 正答率(トレーニング) = 0.83
#                 : 840. 正答率(テスト) = 0.7822
# Generation: 850. 正答率(トレーニング) = 0.87
#                 : 850. 正答率(テスト) = 0.7897
# Generation: 860. 正答率(トレーニング) = 0.8
#                 : 860. 正答率(テスト) = 0.7965
# Generation: 870. 正答率(トレーニング) = 0.89
#                 : 870. 正答率(テスト) = 0.7962
# Generation: 880. 正答率(トレーニング) = 0.84
#                 : 880. 正答率(テスト) = 0.8059
# Generation: 890. 正答率(トレーニング) = 0.8
#                 : 890. 正答率(テスト) = 0.7695
# Generation: 900. 正答率(トレーニング) = 0.87
#                 : 900. 正答率(テスト) = 0.8031
# Generation: 910. 正答率(トレーニング) = 0.8
#                 : 910. 正答率(テスト) = 0.7963
# Generation: 920. 正答率(トレーニング) = 0.78
#                 : 920. 正答率(テスト) = 0.8118
# Generation: 930. 正答率(トレーニング) = 0.88
#                 : 930. 正答率(テスト) = 0.8211
# Generation: 940. 正答率(トレーニング) = 0.83
#                 : 940. 正答率(テスト) = 0.826
# Generation: 950. 正答率(トレーニング) = 0.81
#                 : 950. 正答率(テスト) = 0.7992
# Generation: 960. 正答率(トレーニング) = 0.85
#                 : 960. 正答率(テスト) = 0.8065
# Generation: 970. 正答率(トレーニング) = 0.85
#                 : 970. 正答率(テスト) = 0.8316
# Generation: 980. 正答率(トレーニング) = 0.85
#                 : 980. 正答率(テスト) = 0.8203
# Generation: 990. 正答率(トレーニング) = 0.88
#                 : 990. 正答率(テスト) = 0.8303
# Generation: 1000. 正答率(トレーニング) = 0.86
#                 : 1000. 正答率(テスト) = 0.8185
# Generation: 1010. 正答率(トレーニング) = 0.77
#                 : 1010. 正答率(テスト) = 0.8221
# Generation: 1020. 正答率(トレーニング) = 0.78
#                 : 1020. 正答率(テスト) = 0.8328
# Generation: 1030. 正答率(トレーニング) = 0.89
#                 : 1030. 正答率(テスト) = 0.8091
# Generation: 1040. 正答率(トレーニング) = 0.91
#                 : 1040. 正答率(テスト) = 0.8419
# Generation: 1050. 正答率(トレーニング) = 0.81
#                 : 1050. 正答率(テスト) = 0.8391
# Generation: 1060. 正答率(トレーニング) = 0.87
#                 : 1060. 正答率(テスト) = 0.8404
# Generation: 1070. 正答率(トレーニング) = 0.85
#                 : 1070. 正答率(テスト) = 0.8335
# Generation: 1080. 正答率(トレーニング) = 0.88
#                 : 1080. 正答率(テスト) = 0.8409
# Generation: 1090. 正答率(トレーニング) = 0.82
#                 : 1090. 正答率(テスト) = 0.8429
# Generation: 1100. 正答率(トレーニング) = 0.83
#                 : 1100. 正答率(テスト) = 0.8295
# Generation: 1110. 正答率(トレーニング) = 0.88
#                 : 1110. 正答率(テスト) = 0.8213
# Generation: 1120. 正答率(トレーニング) = 0.88
#                 : 1120. 正答率(テスト) = 0.8439
# Generation: 1130. 正答率(トレーニング) = 0.84
#                 : 1130. 正答率(テスト) = 0.8322
# Generation: 1140. 正答率(トレーニング) = 0.88
#                 : 1140. 正答率(テスト) = 0.8449
# Generation: 1150. 正答率(トレーニング) = 0.82
#                 : 1150. 正答率(テスト) = 0.8472
# Generation: 1160. 正答率(トレーニング) = 0.9
#                 : 1160. 正答率(テスト) = 0.8522
# Generation: 1170. 正答率(トレーニング) = 0.88
#                 : 1170. 正答率(テスト) = 0.8463
# Generation: 1180. 正答率(トレーニング) = 0.89
#                 : 1180. 正答率(テスト) = 0.8338
# Generation: 1190. 正答率(トレーニング) = 0.9
#                 : 1190. 正答率(テスト) = 0.8466
# Generation: 1200. 正答率(トレーニング) = 0.89
#                 : 1200. 正答率(テスト) = 0.8491
# Generation: 1210. 正答率(トレーニング) = 0.9
#                 : 1210. 正答率(テスト) = 0.8575
# Generation: 1220. 正答率(トレーニング) = 0.87
#                 : 1220. 正答率(テスト) = 0.8525
# Generation: 1230. 正答率(トレーニング) = 0.9
#                 : 1230. 正答率(テスト) = 0.8607
# Generation: 1240. 正答率(トレーニング) = 0.89
#                 : 1240. 正答率(テスト) = 0.859
# Generation: 1250. 正答率(トレーニング) = 0.87
#                 : 1250. 正答率(テスト) = 0.8663
# Generation: 1260. 正答率(トレーニング) = 0.93
#                 : 1260. 正答率(テスト) = 0.8477
# Generation: 1270. 正答率(トレーニング) = 0.9
#                 : 1270. 正答率(テスト) = 0.8623
# Generation: 1280. 正答率(トレーニング) = 0.91
#                 : 1280. 正答率(テスト) = 0.8584
# Generation: 1290. 正答率(トレーニング) = 0.93
#                 : 1290. 正答率(テスト) = 0.8642
# Generation: 1300. 正答率(トレーニング) = 0.89
#                 : 1300. 正答率(テスト) = 0.8661
# Generation: 1310. 正答率(トレーニング) = 0.87
#                 : 1310. 正答率(テスト) = 0.8701
# Generation: 1320. 正答率(トレーニング) = 0.89
#                 : 1320. 正答率(テスト) = 0.8722
# Generation: 1330. 正答率(トレーニング) = 0.9
#                 : 1330. 正答率(テスト) = 0.8674
# Generation: 1340. 正答率(トレーニング) = 0.93
#                 : 1340. 正答率(テスト) = 0.872
# Generation: 1350. 正答率(トレーニング) = 0.9
#                 : 1350. 正答率(テスト) = 0.862
# Generation: 1360. 正答率(トレーニング) = 0.89
#                 : 1360. 正答率(テスト) = 0.875
# Generation: 1370. 正答率(トレーニング) = 0.92
#                 : 1370. 正答率(テスト) = 0.8741
# Generation: 1380. 正答率(トレーニング) = 0.89
#                 : 1380. 正答率(テスト) = 0.8709
# Generation: 1390. 正答率(トレーニング) = 0.92
#                 : 1390. 正答率(テスト) = 0.8672
# Generation: 1400. 正答率(トレーニング) = 0.91
#                 : 1400. 正答率(テスト) = 0.8703
# Generation: 1410. 正答率(トレーニング) = 0.93
#                 : 1410. 正答率(テスト) = 0.8733
# Generation: 1420. 正答率(トレーニング) = 0.88
#                 : 1420. 正答率(テスト) = 0.8703
# Generation: 1430. 正答率(トレーニング) = 0.88
#                 : 1430. 正答率(テスト) = 0.8845
# Generation: 1440. 正答率(トレーニング) = 0.95
#                 : 1440. 正答率(テスト) = 0.8806
# Generation: 1450. 正答率(トレーニング) = 0.89
#                 : 1450. 正答率(テスト) = 0.8845
# Generation: 1460. 正答率(トレーニング) = 0.96
#                 : 1460. 正答率(テスト) = 0.8819
# Generation: 1470. 正答率(トレーニング) = 0.94
#                 : 1470. 正答率(テスト) = 0.8824
# Generation: 1480. 正答率(トレーニング) = 0.97
#                 : 1480. 正答率(テスト) = 0.8884
# Generation: 1490. 正答率(トレーニング) = 0.89
#                 : 1490. 正答率(テスト) = 0.8888
# Generation: 1500. 正答率(トレーニング) = 0.93
#                 : 1500. 正答率(テスト) = 0.8875
# Generation: 1510. 正答率(トレーニング) = 0.93
#                 : 1510. 正答率(テスト) = 0.8901
# Generation: 1520. 正答率(トレーニング) = 0.89
#                 : 1520. 正答率(テスト) = 0.8829
# Generation: 1530. 正答率(トレーニング) = 0.91
#                 : 1530. 正答率(テスト) = 0.883
# Generation: 1540. 正答率(トレーニング) = 0.92
#                 : 1540. 正答率(テスト) = 0.884
# Generation: 1550. 正答率(トレーニング) = 0.94
#                 : 1550. 正答率(テスト) = 0.8936
# Generation: 1560. 正答率(トレーニング) = 0.95
#                 : 1560. 正答率(テスト) = 0.8928
# Generation: 1570. 正答率(トレーニング) = 0.91
#                 : 1570. 正答率(テスト) = 0.894
# Generation: 1580. 正答率(トレーニング) = 0.91
#                 : 1580. 正答率(テスト) = 0.8944
# Generation: 1590. 正答率(トレーニング) = 0.94
#                 : 1590. 正答率(テスト) = 0.8958
# Generation: 1600. 正答率(トレーニング) = 0.88
#                 : 1600. 正答率(テスト) = 0.8965
# Generation: 1610. 正答率(トレーニング) = 0.93
#                 : 1610. 正答率(テスト) = 0.897
# Generation: 1620. 正答率(トレーニング) = 0.92
#                 : 1620. 正答率(テスト) = 0.9022
# Generation: 1630. 正答率(トレーニング) = 0.91
#                 : 1630. 正答率(テスト) = 0.8852
# Generation: 1640. 正答率(トレーニング) = 0.96
#                 : 1640. 正答率(テスト) = 0.9005
# Generation: 1650. 正答率(トレーニング) = 0.93
#                 : 1650. 正答率(テスト) = 0.8932
# Generation: 1660. 正答率(トレーニング) = 0.92
#                 : 1660. 正答率(テスト) = 0.8992
# Generation: 1670. 正答率(トレーニング) = 0.96
#                 : 1670. 正答率(テスト) = 0.8998
# Generation: 1680. 正答率(トレーニング) = 0.96
#                 : 1680. 正答率(テスト) = 0.9038
# Generation: 1690. 正答率(トレーニング) = 0.91
#                 : 1690. 正答率(テスト) = 0.9007
# Generation: 1700. 正答率(トレーニング) = 0.92
#                 : 1700. 正答率(テスト) = 0.8954
# Generation: 1710. 正答率(トレーニング) = 0.93
#                 : 1710. 正答率(テスト) = 0.9045
# Generation: 1720. 正答率(トレーニング) = 0.94
#                 : 1720. 正答率(テスト) = 0.8936
# Generation: 1730. 正答率(トレーニング) = 0.9
#                 : 1730. 正答率(テスト) = 0.9058
# Generation: 1740. 正答率(トレーニング) = 0.91
#                 : 1740. 正答率(テスト) = 0.8926
# Generation: 1750. 正答率(トレーニング) = 0.9
#                 : 1750. 正答率(テスト) = 0.8998
# Generation: 1760. 正答率(トレーニング) = 0.85
#                 : 1760. 正答率(テスト) = 0.9052
# Generation: 1770. 正答率(トレーニング) = 0.92
#                 : 1770. 正答率(テスト) = 0.9071
# Generation: 1780. 正答率(トレーニング) = 0.98
#                 : 1780. 正答率(テスト) = 0.9082
# Generation: 1790. 正答率(トレーニング) = 0.95
#                 : 1790. 正答率(テスト) = 0.9063
# Generation: 1800. 正答率(トレーニング) = 0.93
#                 : 1800. 正答率(テスト) = 0.9069
# Generation: 1810. 正答率(トレーニング) = 0.89
#                 : 1810. 正答率(テスト) = 0.8986
# Generation: 1820. 正答率(トレーニング) = 0.93
#                 : 1820. 正答率(テスト) = 0.9045
# Generation: 1830. 正答率(トレーニング) = 0.92
#                 : 1830. 正答率(テスト) = 0.9107
# Generation: 1840. 正答率(トレーニング) = 0.93
#                 : 1840. 正答率(テスト) = 0.905
# Generation: 1850. 正答率(トレーニング) = 0.98
#                 : 1850. 正答率(テスト) = 0.9076
# Generation: 1860. 正答率(トレーニング) = 0.89
#                 : 1860. 正答率(テスト) = 0.9055
# Generation: 1870. 正答率(トレーニング) = 0.94
#                 : 1870. 正答率(テスト) = 0.9081
# Generation: 1880. 正答率(トレーニング) = 0.94
#                 : 1880. 正答率(テスト) = 0.9071
# Generation: 1890. 正答率(トレーニング) = 0.91
#                 : 1890. 正答率(テスト) = 0.9076
# Generation: 1900. 正答率(トレーニング) = 0.97
#                 : 1900. 正答率(テスト) = 0.9149
# Generation: 1910. 正答率(トレーニング) = 0.96
#                 : 1910. 正答率(テスト) = 0.9105
# Generation: 1920. 正答率(トレーニング) = 0.95
#                 : 1920. 正答率(テスト) = 0.908
# Generation: 1930. 正答率(トレーニング) = 0.95
#                 : 1930. 正答率(テスト) = 0.916
# Generation: 1940. 正答率(トレーニング) = 0.92
#                 : 1940. 正答率(テスト) = 0.9151
# Generation: 1950. 正答率(トレーニング) = 0.94
#                 : 1950. 正答率(テスト) = 0.9159
# Generation: 1960. 正答率(トレーニング) = 0.93
#                 : 1960. 正答率(テスト) = 0.9147
# Generation: 1970. 正答率(トレーニング) = 0.92
#                 : 1970. 正答率(テスト) = 0.9114
# Generation: 1980. 正答率(トレーニング) = 0.93
#                 : 1980. 正答率(テスト) = 0.9177
# Generation: 1990. 正答率(トレーニング) = 0.93
#                 : 1990. 正答率(テスト) = 0.9188
# Generation: 2000. 正答率(トレーニング) = 0.96
#                 : 2000. 正答率(テスト) = 0.911

# %% [markdown]
# ## sigmoid - Xavier

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std='Xavier')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.08
#                 : 10. 正答率(テスト) = 0.1028
# Generation: 20. 正答率(トレーニング) = 0.12
#                 : 20. 正答率(テスト) = 0.1013
# Generation: 30. 正答率(トレーニング) = 0.17
#                 : 30. 正答率(テスト) = 0.1028
# Generation: 40. 正答率(トレーニング) = 0.09
#                 : 40. 正答率(テスト) = 0.133
# Generation: 50. 正答率(トレーニング) = 0.13
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.29
#                 : 60. 正答率(テスト) = 0.209
# Generation: 70. 正答率(トレーニング) = 0.27
#                 : 70. 正答率(テスト) = 0.2465
# Generation: 80. 正答率(トレーニング) = 0.33
#                 : 80. 正答率(テスト) = 0.2992
# Generation: 90. 正答率(トレーニング) = 0.32
#                 : 90. 正答率(テスト) = 0.2376
# Generation: 100. 正答率(トレーニング) = 0.35
#                 : 100. 正答率(テスト) = 0.3199
# Generation: 110. 正答率(トレーニング) = 0.32
#                 : 110. 正答率(テスト) = 0.3741
# Generation: 120. 正答率(トレーニング) = 0.21
#                 : 120. 正答率(テスト) = 0.2111
# Generation: 130. 正答率(トレーニング) = 0.2
#                 : 130. 正答率(テスト) = 0.1877
# Generation: 140. 正答率(トレーニング) = 0.25
#                 : 140. 正答率(テスト) = 0.2058
# Generation: 150. 正答率(トレーニング) = 0.18
#                 : 150. 正答率(テスト) = 0.1402
# Generation: 160. 正答率(トレーニング) = 0.3
#                 : 160. 正答率(テスト) = 0.2827
# Generation: 170. 正答率(トレーニング) = 0.27
#                 : 170. 正答率(テスト) = 0.2211
# Generation: 180. 正答率(トレーニング) = 0.36
#                 : 180. 正答率(テスト) = 0.3542
# Generation: 190. 正答率(トレーニング) = 0.29
#                 : 190. 正答率(テスト) = 0.2615
# Generation: 200. 正答率(トレーニング) = 0.33
#                 : 200. 正答率(テスト) = 0.2969
# Generation: 210. 正答率(トレーニング) = 0.31
#                 : 210. 正答率(テスト) = 0.3183
# Generation: 220. 正答率(トレーニング) = 0.39
#                 : 220. 正答率(テスト) = 0.3889
# Generation: 230. 正答率(トレーニング) = 0.35
#                 : 230. 正答率(テスト) = 0.4244
# Generation: 240. 正答率(トレーニング) = 0.47
#                 : 240. 正答率(テスト) = 0.3924
# Generation: 250. 正答率(トレーニング) = 0.45
#                 : 250. 正答率(テスト) = 0.3642
# Generation: 260. 正答率(トレーニング) = 0.39
#                 : 260. 正答率(テスト) = 0.3459
# Generation: 270. 正答率(トレーニング) = 0.35
#                 : 270. 正答率(テスト) = 0.341
# Generation: 280. 正答率(トレーニング) = 0.47
#                 : 280. 正答率(テスト) = 0.3634
# Generation: 290. 正答率(トレーニング) = 0.38
#                 : 290. 正答率(テスト) = 0.3509
# Generation: 300. 正答率(トレーニング) = 0.38
#                 : 300. 正答率(テスト) = 0.3951
# Generation: 310. 正答率(トレーニング) = 0.52
#                 : 310. 正答率(テスト) = 0.4486
# Generation: 320. 正答率(トレーニング) = 0.54
#                 : 320. 正答率(テスト) = 0.4879
# Generation: 330. 正答率(トレーニング) = 0.44
#                 : 330. 正答率(テスト) = 0.4735
# Generation: 340. 正答率(トレーニング) = 0.55
#                 : 340. 正答率(テスト) = 0.4909
# Generation: 350. 正答率(トレーニング) = 0.5
#                 : 350. 正答率(テスト) = 0.4403
# Generation: 360. 正答率(トレーニング) = 0.53
#                 : 360. 正答率(テスト) = 0.4621
# Generation: 370. 正答率(トレーニング) = 0.44
#                 : 370. 正答率(テスト) = 0.4967
# Generation: 380. 正答率(トレーニング) = 0.43
#                 : 380. 正答率(テスト) = 0.5054
# Generation: 390. 正答率(トレーニング) = 0.5
#                 : 390. 正答率(テスト) = 0.5414
# Generation: 400. 正答率(トレーニング) = 0.52
#                 : 400. 正答率(テスト) = 0.5197
# Generation: 410. 正答率(トレーニング) = 0.6
#                 : 410. 正答率(テスト) = 0.5197
# Generation: 420. 正答率(トレーニング) = 0.55
#                 : 420. 正答率(テスト) = 0.5306
# Generation: 430. 正答率(トレーニング) = 0.57
#                 : 430. 正答率(テスト) = 0.5484
# Generation: 440. 正答率(トレーニング) = 0.55
#                 : 440. 正答率(テスト) = 0.5193
# Generation: 450. 正答率(トレーニング) = 0.55
#                 : 450. 正答率(テスト) = 0.4936
# Generation: 460. 正答率(トレーニング) = 0.49
#                 : 460. 正答率(テスト) = 0.4827
# Generation: 470. 正答率(トレーニング) = 0.51
#                 : 470. 正答率(テスト) = 0.5259
# Generation: 480. 正答率(トレーニング) = 0.44
#                 : 480. 正答率(テスト) = 0.5301
# Generation: 490. 正答率(トレーニング) = 0.53
#                 : 490. 正答率(テスト) = 0.531
# Generation: 500. 正答率(トレーニング) = 0.5
#                 : 500. 正答率(テスト) = 0.5464
# Generation: 510. 正答率(トレーニング) = 0.63
#                 : 510. 正答率(テスト) = 0.5723
# Generation: 520. 正答率(トレーニング) = 0.67
#                 : 520. 正答率(テスト) = 0.5585
# Generation: 530. 正答率(トレーニング) = 0.56
#                 : 530. 正答率(テスト) = 0.5813
# Generation: 540. 正答率(トレーニング) = 0.56
#                 : 540. 正答率(テスト) = 0.5789
# Generation: 550. 正答率(トレーニング) = 0.53
#                 : 550. 正答率(テスト) = 0.5581
# Generation: 560. 正答率(トレーニング) = 0.55
#                 : 560. 正答率(テスト) = 0.5811
# Generation: 570. 正答率(トレーニング) = 0.56
#                 : 570. 正答率(テスト) = 0.5959
# Generation: 580. 正答率(トレーニング) = 0.58
#                 : 580. 正答率(テスト) = 0.6109
# Generation: 590. 正答率(トレーニング) = 0.68
#                 : 590. 正答率(テスト) = 0.6111
# Generation: 600. 正答率(トレーニング) = 0.65
#                 : 600. 正答率(テスト) = 0.6147
# Generation: 610. 正答率(トレーニング) = 0.63
#                 : 610. 正答率(テスト) = 0.6126
# Generation: 620. 正答率(トレーニング) = 0.61
#                 : 620. 正答率(テスト) = 0.6102
# Generation: 630. 正答率(トレーニング) = 0.6
#                 : 630. 正答率(テスト) = 0.6183
# Generation: 640. 正答率(トレーニング) = 0.62
#                 : 640. 正答率(テスト) = 0.6258
# Generation: 650. 正答率(トレーニング) = 0.66
#                 : 650. 正答率(テスト) = 0.6307
# Generation: 660. 正答率(トレーニング) = 0.67
#                 : 660. 正答率(テスト) = 0.6462
# Generation: 670. 正答率(トレーニング) = 0.69
#                 : 670. 正答率(テスト) = 0.6496
# Generation: 680. 正答率(トレーニング) = 0.55
#                 : 680. 正答率(テスト) = 0.6611
# Generation: 690. 正答率(トレーニング) = 0.64
#                 : 690. 正答率(テスト) = 0.6584
# Generation: 700. 正答率(トレーニング) = 0.67
#                 : 700. 正答率(テスト) = 0.667
# Generation: 710. 正答率(トレーニング) = 0.68
#                 : 710. 正答率(テスト) = 0.6775
# Generation: 720. 正答率(トレーニング) = 0.75
#                 : 720. 正答率(テスト) = 0.681
# Generation: 730. 正答率(トレーニング) = 0.67
#                 : 730. 正答率(テスト) = 0.6886
# Generation: 740. 正答率(トレーニング) = 0.79
#                 : 740. 正答率(テスト) = 0.7031
# Generation: 750. 正答率(トレーニング) = 0.67
#                 : 750. 正答率(テスト) = 0.7056
# Generation: 760. 正答率(トレーニング) = 0.67
#                 : 760. 正答率(テスト) = 0.7084
# Generation: 770. 正答率(トレーニング) = 0.67
#                 : 770. 正答率(テスト) = 0.7102
# Generation: 780. 正答率(トレーニング) = 0.67
#                 : 780. 正答率(テスト) = 0.7198
# Generation: 790. 正答率(トレーニング) = 0.72
#                 : 790. 正答率(テスト) = 0.7136
# Generation: 800. 正答率(トレーニング) = 0.77
#                 : 800. 正答率(テスト) = 0.733
# Generation: 810. 正答率(トレーニング) = 0.72
#                 : 810. 正答率(テスト) = 0.7353
# Generation: 820. 正答率(トレーニング) = 0.75
#                 : 820. 正答率(テスト) = 0.7277
# Generation: 830. 正答率(トレーニング) = 0.67
#                 : 830. 正答率(テスト) = 0.7308
# Generation: 840. 正答率(トレーニング) = 0.79
#                 : 840. 正答率(テスト) = 0.7429
# Generation: 850. 正答率(トレーニング) = 0.71
#                 : 850. 正答率(テスト) = 0.7369
# Generation: 860. 正答率(トレーニング) = 0.74
#                 : 860. 正答率(テスト) = 0.7469
# Generation: 870. 正答率(トレーニング) = 0.78
#                 : 870. 正答率(テスト) = 0.7458
# Generation: 880. 正答率(トレーニング) = 0.74
#                 : 880. 正答率(テスト) = 0.7524
# Generation: 890. 正答率(トレーニング) = 0.72
#                 : 890. 正答率(テスト) = 0.7563
# Generation: 900. 正答率(トレーニング) = 0.76
#                 : 900. 正答率(テスト) = 0.7672
# Generation: 910. 正答率(トレーニング) = 0.7
#                 : 910. 正答率(テスト) = 0.7647
# Generation: 920. 正答率(トレーニング) = 0.76
#                 : 920. 正答率(テスト) = 0.7703
# Generation: 930. 正答率(トレーニング) = 0.73
#                 : 930. 正答率(テスト) = 0.7776
# Generation: 940. 正答率(トレーニング) = 0.86
#                 : 940. 正答率(テスト) = 0.7738
# Generation: 950. 正答率(トレーニング) = 0.7
#                 : 950. 正答率(テスト) = 0.7722
# Generation: 960. 正答率(トレーニング) = 0.77
#                 : 960. 正答率(テスト) = 0.7742
# Generation: 970. 正答率(トレーニング) = 0.71
#                 : 970. 正答率(テスト) = 0.777
# Generation: 980. 正答率(トレーニング) = 0.79
#                 : 980. 正答率(テスト) = 0.7836
# Generation: 990. 正答率(トレーニング) = 0.78
#                 : 990. 正答率(テスト) = 0.785
# Generation: 1000. 正答率(トレーニング) = 0.8
#                 : 1000. 正答率(テスト) = 0.779
# Generation: 1010. 正答率(トレーニング) = 0.78
#                 : 1010. 正答率(テスト) = 0.7838
# Generation: 1020. 正答率(トレーニング) = 0.74
#                 : 1020. 正答率(テスト) = 0.7884
# Generation: 1030. 正答率(トレーニング) = 0.77
#                 : 1030. 正答率(テスト) = 0.7946
# Generation: 1040. 正答率(トレーニング) = 0.8
#                 : 1040. 正答率(テスト) = 0.7901
# Generation: 1050. 正答率(トレーニング) = 0.78
#                 : 1050. 正答率(テスト) = 0.7889
# Generation: 1060. 正答率(トレーニング) = 0.73
#                 : 1060. 正答率(テスト) = 0.7899
# Generation: 1070. 正答率(トレーニング) = 0.82
#                 : 1070. 正答率(テスト) = 0.7894
# Generation: 1080. 正答率(トレーニング) = 0.88
#                 : 1080. 正答率(テスト) = 0.796
# Generation: 1090. 正答率(トレーニング) = 0.79
#                 : 1090. 正答率(テスト) = 0.7948
# Generation: 1100. 正答率(トレーニング) = 0.82
#                 : 1100. 正答率(テスト) = 0.795
# Generation: 1110. 正答率(トレーニング) = 0.82
#                 : 1110. 正答率(テスト) = 0.7968
# Generation: 1120. 正答率(トレーニング) = 0.79
#                 : 1120. 正答率(テスト) = 0.7989
# Generation: 1130. 正答率(トレーニング) = 0.73
#                 : 1130. 正答率(テスト) = 0.8014
# Generation: 1140. 正答率(トレーニング) = 0.76
#                 : 1140. 正答率(テスト) = 0.8048
# Generation: 1150. 正答率(トレーニング) = 0.76
#                 : 1150. 正答率(テスト) = 0.8027
# Generation: 1160. 正答率(トレーニング) = 0.84
#                 : 1160. 正答率(テスト) = 0.8008
# Generation: 1170. 正答率(トレーニング) = 0.81
#                 : 1170. 正答率(テスト) = 0.8054
# Generation: 1180. 正答率(トレーニング) = 0.87
#                 : 1180. 正答率(テスト) = 0.8062
# Generation: 1190. 正答率(トレーニング) = 0.76
#                 : 1190. 正答率(テスト) = 0.8107
# Generation: 1200. 正答率(トレーニング) = 0.83
#                 : 1200. 正答率(テスト) = 0.8105
# Generation: 1210. 正答率(トレーニング) = 0.83
#                 : 1210. 正答率(テスト) = 0.8126
# Generation: 1220. 正答率(トレーニング) = 0.79
#                 : 1220. 正答率(テスト) = 0.8116
# Generation: 1230. 正答率(トレーニング) = 0.8
#                 : 1230. 正答率(テスト) = 0.8144
# Generation: 1240. 正答率(トレーニング) = 0.84
#                 : 1240. 正答率(テスト) = 0.8146
# Generation: 1250. 正答率(トレーニング) = 0.85
#                 : 1250. 正答率(テスト) = 0.8148
# Generation: 1260. 正答率(トレーニング) = 0.8
#                 : 1260. 正答率(テスト) = 0.8159
# Generation: 1270. 正答率(トレーニング) = 0.89
#                 : 1270. 正答率(テスト) = 0.8173
# Generation: 1280. 正答率(トレーニング) = 0.81
#                 : 1280. 正答率(テスト) = 0.8182
# Generation: 1290. 正答率(トレーニング) = 0.86
#                 : 1290. 正答率(テスト) = 0.8169
# Generation: 1300. 正答率(トレーニング) = 0.8
#                 : 1300. 正答率(テスト) = 0.8204
# Generation: 1310. 正答率(トレーニング) = 0.83
#                 : 1310. 正答率(テスト) = 0.8228
# Generation: 1320. 正答率(トレーニング) = 0.82
#                 : 1320. 正答率(テスト) = 0.8237
# Generation: 1330. 正答率(トレーニング) = 0.82
#                 : 1330. 正答率(テスト) = 0.8232
# Generation: 1340. 正答率(トレーニング) = 0.86
#                 : 1340. 正答率(テスト) = 0.8268
# Generation: 1350. 正答率(トレーニング) = 0.81
#                 : 1350. 正答率(テスト) = 0.8271
# Generation: 1360. 正答率(トレーニング) = 0.87
#                 : 1360. 正答率(テスト) = 0.8234
# Generation: 1370. 正答率(トレーニング) = 0.8
#                 : 1370. 正答率(テスト) = 0.8307
# Generation: 1380. 正答率(トレーニング) = 0.82
#                 : 1380. 正答率(テスト) = 0.8287
# Generation: 1390. 正答率(トレーニング) = 0.81
#                 : 1390. 正答率(テスト) = 0.8301
# Generation: 1400. 正答率(トレーニング) = 0.87
#                 : 1400. 正答率(テスト) = 0.8322
# Generation: 1410. 正答率(トレーニング) = 0.88
#                 : 1410. 正答率(テスト) = 0.8327
# Generation: 1420. 正答率(トレーニング) = 0.8
#                 : 1420. 正答率(テスト) = 0.8339
# Generation: 1430. 正答率(トレーニング) = 0.85
#                 : 1430. 正答率(テスト) = 0.8338
# Generation: 1440. 正答率(トレーニング) = 0.9
#                 : 1440. 正答率(テスト) = 0.8348
# Generation: 1450. 正答率(トレーニング) = 0.82
#                 : 1450. 正答率(テスト) = 0.839
# Generation: 1460. 正答率(トレーニング) = 0.79
#                 : 1460. 正答率(テスト) = 0.8389
# Generation: 1470. 正答率(トレーニング) = 0.84
#                 : 1470. 正答率(テスト) = 0.8388
# Generation: 1480. 正答率(トレーニング) = 0.89
#                 : 1480. 正答率(テスト) = 0.839
# Generation: 1490. 正答率(トレーニング) = 0.87
#                 : 1490. 正答率(テスト) = 0.8402
# Generation: 1500. 正答率(トレーニング) = 0.85
#                 : 1500. 正答率(テスト) = 0.8429
# Generation: 1510. 正答率(トレーニング) = 0.79
#                 : 1510. 正答率(テスト) = 0.8434
# Generation: 1520. 正答率(トレーニング) = 0.86
#                 : 1520. 正答率(テスト) = 0.8437
# Generation: 1530. 正答率(トレーニング) = 0.84
#                 : 1530. 正答率(テスト) = 0.8426
# Generation: 1540. 正答率(トレーニング) = 0.85
#                 : 1540. 正答率(テスト) = 0.8459
# Generation: 1550. 正答率(トレーニング) = 0.81
#                 : 1550. 正答率(テスト) = 0.8468
# Generation: 1560. 正答率(トレーニング) = 0.84
#                 : 1560. 正答率(テスト) = 0.8445
# Generation: 1570. 正答率(トレーニング) = 0.79
#                 : 1570. 正答率(テスト) = 0.8477
# Generation: 1580. 正答率(トレーニング) = 0.86
#                 : 1580. 正答率(テスト) = 0.8493
# Generation: 1590. 正答率(トレーニング) = 0.8
#                 : 1590. 正答率(テスト) = 0.8524
# Generation: 1600. 正答率(トレーニング) = 0.81
#                 : 1600. 正答率(テスト) = 0.8519
# Generation: 1610. 正答率(トレーニング) = 0.86
#                 : 1610. 正答率(テスト) = 0.8525
# Generation: 1620. 正答率(トレーニング) = 0.85
#                 : 1620. 正答率(テスト) = 0.8501
# Generation: 1630. 正答率(トレーニング) = 0.87
#                 : 1630. 正答率(テスト) = 0.8531
# Generation: 1640. 正答率(トレーニング) = 0.89
#                 : 1640. 正答率(テスト) = 0.8546
# Generation: 1650. 正答率(トレーニング) = 0.86
#                 : 1650. 正答率(テスト) = 0.8547
# Generation: 1660. 正答率(トレーニング) = 0.87
#                 : 1660. 正答率(テスト) = 0.8546
# Generation: 1670. 正答率(トレーニング) = 0.87
#                 : 1670. 正答率(テスト) = 0.8563
# Generation: 1680. 正答率(トレーニング) = 0.83
#                 : 1680. 正答率(テスト) = 0.8567
# Generation: 1690. 正答率(トレーニング) = 0.86
#                 : 1690. 正答率(テスト) = 0.8564
# Generation: 1700. 正答率(トレーニング) = 0.79
#                 : 1700. 正答率(テスト) = 0.8562
# Generation: 1710. 正答率(トレーニング) = 0.84
#                 : 1710. 正答率(テスト) = 0.8586
# Generation: 1720. 正答率(トレーニング) = 0.89
#                 : 1720. 正答率(テスト) = 0.8609
# Generation: 1730. 正答率(トレーニング) = 0.86
#                 : 1730. 正答率(テスト) = 0.8593
# Generation: 1740. 正答率(トレーニング) = 0.85
#                 : 1740. 正答率(テスト) = 0.8591
# Generation: 1750. 正答率(トレーニング) = 0.89
#                 : 1750. 正答率(テスト) = 0.8604
# Generation: 1760. 正答率(トレーニング) = 0.85
#                 : 1760. 正答率(テスト) = 0.8605
# Generation: 1770. 正答率(トレーニング) = 0.84
#                 : 1770. 正答率(テスト) = 0.8617
# Generation: 1780. 正答率(トレーニング) = 0.88
#                 : 1780. 正答率(テスト) = 0.8592
# Generation: 1790. 正答率(トレーニング) = 0.91
#                 : 1790. 正答率(テスト) = 0.8624
# Generation: 1800. 正答率(トレーニング) = 0.87
#                 : 1800. 正答率(テスト) = 0.8641
# Generation: 1810. 正答率(トレーニング) = 0.88
#                 : 1810. 正答率(テスト) = 0.8674
# Generation: 1820. 正答率(トレーニング) = 0.86
#                 : 1820. 正答率(テスト) = 0.8656
# Generation: 1830. 正答率(トレーニング) = 0.91
#                 : 1830. 正答率(テスト) = 0.8648
# Generation: 1840. 正答率(トレーニング) = 0.9
#                 : 1840. 正答率(テスト) = 0.8648
# Generation: 1850. 正答率(トレーニング) = 0.88
#                 : 1850. 正答率(テスト) = 0.8651
# Generation: 1860. 正答率(トレーニング) = 0.84
#                 : 1860. 正答率(テスト) = 0.8639
# Generation: 1870. 正答率(トレーニング) = 0.81
#                 : 1870. 正答率(テスト) = 0.8642
# Generation: 1880. 正答率(トレーニング) = 0.88
#                 : 1880. 正答率(テスト) = 0.8681
# Generation: 1890. 正答率(トレーニング) = 0.85
#                 : 1890. 正答率(テスト) = 0.8671
# Generation: 1900. 正答率(トレーニング) = 0.87
#                 : 1900. 正答率(テスト) = 0.8691
# Generation: 1910. 正答率(トレーニング) = 0.86
#                 : 1910. 正答率(テスト) = 0.8673
# Generation: 1920. 正答率(トレーニング) = 0.8
#                 : 1920. 正答率(テスト) = 0.8683
# Generation: 1930. 正答率(トレーニング) = 0.92
#                 : 1930. 正答率(テスト) = 0.8694
# Generation: 1940. 正答率(トレーニング) = 0.85
#                 : 1940. 正答率(テスト) = 0.8715
# Generation: 1950. 正答率(トレーニング) = 0.87
#                 : 1950. 正答率(テスト) = 0.8721
# Generation: 1960. 正答率(トレーニング) = 0.92
#                 : 1960. 正答率(テスト) = 0.8709
# Generation: 1970. 正答率(トレーニング) = 0.89
#                 : 1970. 正答率(テスト) = 0.8685
# Generation: 1980. 正答率(トレーニング) = 0.85
#                 : 1980. 正答率(テスト) = 0.871
# Generation: 1990. 正答率(トレーニング) = 0.89
#                 : 1990. 正答率(テスト) = 0.8718
# Generation: 2000. 正答率(トレーニング) = 0.87
#                 : 2000. 正答率(テスト) = 0.8731

# %% [markdown]
# ## ReLU - He

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

network = MultiLayerNet(input_size=784, hidden_size_list=[50, 100], output_size=10, activation='relu', weight_init_std='He')

iters_num = 2000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.53
#                 : 10. 正答率(テスト) = 0.4908
# Generation: 20. 正答率(トレーニング) = 0.7
#                 : 20. 正答率(テスト) = 0.7128
# Generation: 30. 正答率(トレーニング) = 0.85
#                 : 30. 正答率(テスト) = 0.7541
# Generation: 40. 正答率(トレーニング) = 0.85
#                 : 40. 正答率(テスト) = 0.7942
# Generation: 50. 正答率(トレーニング) = 0.84
#                 : 50. 正答率(テスト) = 0.8243
# Generation: 60. 正答率(トレーニング) = 0.83
#                 : 60. 正答率(テスト) = 0.8016
# Generation: 70. 正答率(トレーニング) = 0.91
#                 : 70. 正答率(テスト) = 0.869
# Generation: 80. 正答率(トレーニング) = 0.92
#                 : 80. 正答率(テスト) = 0.863
# Generation: 90. 正答率(トレーニング) = 0.94
#                 : 90. 正答率(テスト) = 0.8823
# Generation: 100. 正答率(トレーニング) = 0.93
#                 : 100. 正答率(テスト) = 0.8775
# Generation: 110. 正答率(トレーニング) = 0.89
#                 : 110. 正答率(テスト) = 0.8866
# Generation: 120. 正答率(トレーニング) = 0.88
#                 : 120. 正答率(テスト) = 0.8871
# Generation: 130. 正答率(トレーニング) = 0.94
#                 : 130. 正答率(テスト) = 0.8799
# Generation: 140. 正答率(トレーニング) = 0.92
#                 : 140. 正答率(テスト) = 0.891
# Generation: 150. 正答率(トレーニング) = 0.88
#                 : 150. 正答率(テスト) = 0.878
# Generation: 160. 正答率(トレーニング) = 0.9
#                 : 160. 正答率(テスト) = 0.8984
# Generation: 170. 正答率(トレーニング) = 0.93
#                 : 170. 正答率(テスト) = 0.9012
# Generation: 180. 正答率(トレーニング) = 0.97
#                 : 180. 正答率(テスト) = 0.8887
# Generation: 190. 正答率(トレーニング) = 0.93
#                 : 190. 正答率(テスト) = 0.8963
# Generation: 200. 正答率(トレーニング) = 0.98
#                 : 200. 正答率(テスト) = 0.8995
# Generation: 210. 正答率(トレーニング) = 0.96
#                 : 210. 正答率(テスト) = 0.9043
# Generation: 220. 正答率(トレーニング) = 0.93
#                 : 220. 正答率(テスト) = 0.9148
# Generation: 230. 正答率(トレーニング) = 0.94
#                 : 230. 正答率(テスト) = 0.9096
# Generation: 240. 正答率(トレーニング) = 0.94
#                 : 240. 正答率(テスト) = 0.9001
# Generation: 250. 正答率(トレーニング) = 0.92
#                 : 250. 正答率(テスト) = 0.9101
# Generation: 260. 正答率(トレーニング) = 0.92
#                 : 260. 正答率(テスト) = 0.9087
# Generation: 270. 正答率(トレーニング) = 0.96
#                 : 270. 正答率(テスト) = 0.9189
# Generation: 280. 正答率(トレーニング) = 0.93
#                 : 280. 正答率(テスト) = 0.9098
# Generation: 290. 正答率(トレーニング) = 0.93
#                 : 290. 正答率(テスト) = 0.9211
# Generation: 300. 正答率(トレーニング) = 0.93
#                 : 300. 正答率(テスト) = 0.9206
# Generation: 310. 正答率(トレーニング) = 0.91
#                 : 310. 正答率(テスト) = 0.9169
# Generation: 320. 正答率(トレーニング) = 0.92
#                 : 320. 正答率(テスト) = 0.9161
# Generation: 330. 正答率(トレーニング) = 0.92
#                 : 330. 正答率(テスト) = 0.9211
# Generation: 340. 正答率(トレーニング) = 0.93
#                 : 340. 正答率(テスト) = 0.9255
# Generation: 350. 正答率(トレーニング) = 0.92
#                 : 350. 正答率(テスト) = 0.9202
# Generation: 360. 正答率(トレーニング) = 0.94
#                 : 360. 正答率(テスト) = 0.9195
# Generation: 370. 正答率(トレーニング) = 0.96
#                 : 370. 正答率(テスト) = 0.9233
# Generation: 380. 正答率(トレーニング) = 0.94
#                 : 380. 正答率(テスト) = 0.9215
# Generation: 390. 正答率(トレーニング) = 0.92
#                 : 390. 正答率(テスト) = 0.9252
# Generation: 400. 正答率(トレーニング) = 0.95
#                 : 400. 正答率(テスト) = 0.9278
# Generation: 410. 正答率(トレーニング) = 0.96
#                 : 410. 正答率(テスト) = 0.9218
# Generation: 420. 正答率(トレーニング) = 0.97
#                 : 420. 正答率(テスト) = 0.9307
# Generation: 430. 正答率(トレーニング) = 0.9
#                 : 430. 正答率(テスト) = 0.9226
# Generation: 440. 正答率(トレーニング) = 0.98
#                 : 440. 正答率(テスト) = 0.9264
# Generation: 450. 正答率(トレーニング) = 0.97
#                 : 450. 正答率(テスト) = 0.9249
# Generation: 460. 正答率(トレーニング) = 0.98
#                 : 460. 正答率(テスト) = 0.93
# Generation: 470. 正答率(トレーニング) = 0.95
#                 : 470. 正答率(テスト) = 0.9338
# Generation: 480. 正答率(トレーニング) = 0.98
#                 : 480. 正答率(テスト) = 0.9309
# Generation: 490. 正答率(トレーニング) = 0.94
#                 : 490. 正答率(テスト) = 0.9275
# Generation: 500. 正答率(トレーニング) = 0.97
#                 : 500. 正答率(テスト) = 0.9301
# Generation: 510. 正答率(トレーニング) = 0.92
#                 : 510. 正答率(テスト) = 0.9281
# Generation: 520. 正答率(トレーニング) = 0.97
#                 : 520. 正答率(テスト) = 0.9292
# Generation: 530. 正答率(トレーニング) = 0.96
#                 : 530. 正答率(テスト) = 0.9353
# Generation: 540. 正答率(トレーニング) = 0.97
#                 : 540. 正答率(テスト) = 0.9352
# Generation: 550. 正答率(トレーニング) = 0.96
#                 : 550. 正答率(テスト) = 0.9276
# Generation: 560. 正答率(トレーニング) = 0.94
#                 : 560. 正答率(テスト) = 0.9311
# Generation: 570. 正答率(トレーニング) = 0.95
#                 : 570. 正答率(テスト) = 0.9345
# Generation: 580. 正答率(トレーニング) = 0.93
#                 : 580. 正答率(テスト) = 0.9304
# Generation: 590. 正答率(トレーニング) = 0.95
#                 : 590. 正答率(テスト) = 0.9345
# Generation: 600. 正答率(トレーニング) = 0.98
#                 : 600. 正答率(テスト) = 0.9381
# Generation: 610. 正答率(トレーニング) = 0.95
#                 : 610. 正答率(テスト) = 0.9401
# Generation: 620. 正答率(トレーニング) = 0.93
#                 : 620. 正答率(テスト) = 0.9419
# Generation: 630. 正答率(トレーニング) = 0.96
#                 : 630. 正答率(テスト) = 0.9366
# Generation: 640. 正答率(トレーニング) = 0.98
#                 : 640. 正答率(テスト) = 0.9371
# Generation: 650. 正答率(トレーニング) = 0.98
#                 : 650. 正答率(テスト) = 0.9398
# Generation: 660. 正答率(トレーニング) = 0.94
#                 : 660. 正答率(テスト) = 0.9373
# Generation: 670. 正答率(トレーニング) = 0.97
#                 : 670. 正答率(テスト) = 0.9338
# Generation: 680. 正答率(トレーニング) = 0.99
#                 : 680. 正答率(テスト) = 0.9434
# Generation: 690. 正答率(トレーニング) = 0.96
#                 : 690. 正答率(テスト) = 0.9402
# Generation: 700. 正答率(トレーニング) = 0.96
#                 : 700. 正答率(テスト) = 0.9434
# Generation: 710. 正答率(トレーニング) = 0.95
#                 : 710. 正答率(テスト) = 0.9368
# Generation: 720. 正答率(トレーニング) = 0.95
#                 : 720. 正答率(テスト) = 0.9382
# Generation: 730. 正答率(トレーニング) = 0.97
#                 : 730. 正答率(テスト) = 0.9296
# Generation: 740. 正答率(トレーニング) = 0.96
#                 : 740. 正答率(テスト) = 0.9423
# Generation: 750. 正答率(トレーニング) = 0.98
#                 : 750. 正答率(テスト) = 0.9384
# Generation: 760. 正答率(トレーニング) = 0.99
#                 : 760. 正答率(テスト) = 0.9442
# Generation: 770. 正答率(トレーニング) = 0.99
#                 : 770. 正答率(テスト) = 0.9438
# Generation: 780. 正答率(トレーニング) = 0.95
#                 : 780. 正答率(テスト) = 0.9447
# Generation: 790. 正答率(トレーニング) = 0.99
#                 : 790. 正答率(テスト) = 0.9411
# Generation: 800. 正答率(トレーニング) = 0.97
#                 : 800. 正答率(テスト) = 0.9443
# Generation: 810. 正答率(トレーニング) = 0.96
#                 : 810. 正答率(テスト) = 0.946
# Generation: 820. 正答率(トレーニング) = 0.97
#                 : 820. 正答率(テスト) = 0.9434
# Generation: 830. 正答率(トレーニング) = 0.96
#                 : 830. 正答率(テスト) = 0.945
# Generation: 840. 正答率(トレーニング) = 0.98
#                 : 840. 正答率(テスト) = 0.9442
# Generation: 850. 正答率(トレーニング) = 0.98
#                 : 850. 正答率(テスト) = 0.9437
# Generation: 860. 正答率(トレーニング) = 0.96
#                 : 860. 正答率(テスト) = 0.9442
# Generation: 870. 正答率(トレーニング) = 0.95
#                 : 870. 正答率(テスト) = 0.9471
# Generation: 880. 正答率(トレーニング) = 0.99
#                 : 880. 正答率(テスト) = 0.9431
# Generation: 890. 正答率(トレーニング) = 0.97
#                 : 890. 正答率(テスト) = 0.9428
# Generation: 900. 正答率(トレーニング) = 0.99
#                 : 900. 正答率(テスト) = 0.9452
# Generation: 910. 正答率(トレーニング) = 0.99
#                 : 910. 正答率(テスト) = 0.9415
# Generation: 920. 正答率(トレーニング) = 0.94
#                 : 920. 正答率(テスト) = 0.9418
# Generation: 930. 正答率(トレーニング) = 0.98
#                 : 930. 正答率(テスト) = 0.9447
# Generation: 940. 正答率(トレーニング) = 0.98
#                 : 940. 正答率(テスト) = 0.9497
# Generation: 950. 正答率(トレーニング) = 0.98
#                 : 950. 正答率(テスト) = 0.9487
# Generation: 960. 正答率(トレーニング) = 0.99
#                 : 960. 正答率(テスト) = 0.9485
# Generation: 970. 正答率(トレーニング) = 0.97
#                 : 970. 正答率(テスト) = 0.9487
# Generation: 980. 正答率(トレーニング) = 0.96
#                 : 980. 正答率(テスト) = 0.9492
# Generation: 990. 正答率(トレーニング) = 0.98
#                 : 990. 正答率(テスト) = 0.9467
# Generation: 1000. 正答率(トレーニング) = 0.97
#                 : 1000. 正答率(テスト) = 0.9516
# Generation: 1010. 正答率(トレーニング) = 0.95
#                 : 1010. 正答率(テスト) = 0.9496
# Generation: 1020. 正答率(トレーニング) = 0.98
#                 : 1020. 正答率(テスト) = 0.9445
# Generation: 1030. 正答率(トレーニング) = 0.97
#                 : 1030. 正答率(テスト) = 0.9468
# Generation: 1040. 正答率(トレーニング) = 0.99
#                 : 1040. 正答率(テスト) = 0.9518
# Generation: 1050. 正答率(トレーニング) = 0.96
#                 : 1050. 正答率(テスト) = 0.9496
# Generation: 1060. 正答率(トレーニング) = 0.95
#                 : 1060. 正答率(テスト) = 0.9503
# Generation: 1070. 正答率(トレーニング) = 0.99
#                 : 1070. 正答率(テスト) = 0.9496
# Generation: 1080. 正答率(トレーニング) = 0.97
#                 : 1080. 正答率(テスト) = 0.9518
# Generation: 1090. 正答率(トレーニング) = 0.99
#                 : 1090. 正答率(テスト) = 0.9523
# Generation: 1100. 正答率(トレーニング) = 0.94
#                 : 1100. 正答率(テスト) = 0.9499
# Generation: 1110. 正答率(トレーニング) = 0.92
#                 : 1110. 正答率(テスト) = 0.9466
# Generation: 1120. 正答率(トレーニング) = 0.99
#                 : 1120. 正答率(テスト) = 0.95
# Generation: 1130. 正答率(トレーニング) = 0.96
#                 : 1130. 正答率(テスト) = 0.9478
# Generation: 1140. 正答率(トレーニング) = 0.97
#                 : 1140. 正答率(テスト) = 0.9483
# Generation: 1150. 正答率(トレーニング) = 0.99
#                 : 1150. 正答率(テスト) = 0.9471
# Generation: 1160. 正答率(トレーニング) = 0.98
#                 : 1160. 正答率(テスト) = 0.952
# Generation: 1170. 正答率(トレーニング) = 0.98
#                 : 1170. 正答率(テスト) = 0.9448
# Generation: 1180. 正答率(トレーニング) = 0.97
#                 : 1180. 正答率(テスト) = 0.9476
# Generation: 1190. 正答率(トレーニング) = 0.97
#                 : 1190. 正答率(テスト) = 0.9493
# Generation: 1200. 正答率(トレーニング) = 0.97
#                 : 1200. 正答率(テスト) = 0.9497
# Generation: 1210. 正答率(トレーニング) = 0.99
#                 : 1210. 正答率(テスト) = 0.9492
# Generation: 1220. 正答率(トレーニング) = 1.0
#                 : 1220. 正答率(テスト) = 0.9517
# Generation: 1230. 正答率(トレーニング) = 1.0
#                 : 1230. 正答率(テスト) = 0.9538
# Generation: 1240. 正答率(トレーニング) = 0.98
#                 : 1240. 正答率(テスト) = 0.9548
# Generation: 1250. 正答率(トレーニング) = 0.98
#                 : 1250. 正答率(テスト) = 0.9461
# Generation: 1260. 正答率(トレーニング) = 0.97
#                 : 1260. 正答率(テスト) = 0.9497
# Generation: 1270. 正答率(トレーニング) = 0.95
#                 : 1270. 正答率(テスト) = 0.9549
# Generation: 1280. 正答率(トレーニング) = 0.95
#                 : 1280. 正答率(テスト) = 0.9492
# Generation: 1290. 正答率(トレーニング) = 0.96
#                 : 1290. 正答率(テスト) = 0.9537
# Generation: 1300. 正答率(トレーニング) = 0.97
#                 : 1300. 正答率(テスト) = 0.9507
# Generation: 1310. 正答率(トレーニング) = 0.98
#                 : 1310. 正答率(テスト) = 0.9545
# Generation: 1320. 正答率(トレーニング) = 0.99
#                 : 1320. 正答率(テスト) = 0.9556
# Generation: 1330. 正答率(トレーニング) = 0.95
#                 : 1330. 正答率(テスト) = 0.9506
# Generation: 1340. 正答率(トレーニング) = 0.97
#                 : 1340. 正答率(テスト) = 0.9524
# Generation: 1350. 正答率(トレーニング) = 0.97
#                 : 1350. 正答率(テスト) = 0.9576
# Generation: 1360. 正答率(トレーニング) = 1.0
#                 : 1360. 正答率(テスト) = 0.956
# Generation: 1370. 正答率(トレーニング) = 0.95
#                 : 1370. 正答率(テスト) = 0.9557
# Generation: 1380. 正答率(トレーニング) = 0.99
#                 : 1380. 正答率(テスト) = 0.9551
# Generation: 1390. 正答率(トレーニング) = 0.99
#                 : 1390. 正答率(テスト) = 0.955
# Generation: 1400. 正答率(トレーニング) = 0.99
#                 : 1400. 正答率(テスト) = 0.9533
# Generation: 1410. 正答率(トレーニング) = 0.94
#                 : 1410. 正答率(テスト) = 0.9498
# Generation: 1420. 正答率(トレーニング) = 0.96
#                 : 1420. 正答率(テスト) = 0.9549
# Generation: 1430. 正答率(トレーニング) = 0.99
#                 : 1430. 正答率(テスト) = 0.9587
# Generation: 1440. 正答率(トレーニング) = 0.99
#                 : 1440. 正答率(テスト) = 0.9541
# Generation: 1450. 正答率(トレーニング) = 0.94
#                 : 1450. 正答率(テスト) = 0.9514
# Generation: 1460. 正答率(トレーニング) = 0.99
#                 : 1460. 正答率(テスト) = 0.9552
# Generation: 1470. 正答率(トレーニング) = 0.99
#                 : 1470. 正答率(テスト) = 0.9581
# Generation: 1480. 正答率(トレーニング) = 1.0
#                 : 1480. 正答率(テスト) = 0.9568
# Generation: 1490. 正答率(トレーニング) = 0.97
#                 : 1490. 正答率(テスト) = 0.9511
# Generation: 1500. 正答率(トレーニング) = 0.97
#                 : 1500. 正答率(テスト) = 0.9556
# Generation: 1510. 正答率(トレーニング) = 0.99
#                 : 1510. 正答率(テスト) = 0.9453
# Generation: 1520. 正答率(トレーニング) = 0.98
#                 : 1520. 正答率(テスト) = 0.9541
# Generation: 1530. 正答率(トレーニング) = 0.94
#                 : 1530. 正答率(テスト) = 0.9533
# Generation: 1540. 正答率(トレーニング) = 1.0
#                 : 1540. 正答率(テスト) = 0.956
# Generation: 1550. 正答率(トレーニング) = 0.98
#                 : 1550. 正答率(テスト) = 0.9563
# Generation: 1560. 正答率(トレーニング) = 0.98
#                 : 1560. 正答率(テスト) = 0.9581
# Generation: 1570. 正答率(トレーニング) = 0.98
#                 : 1570. 正答率(テスト) = 0.9575
# Generation: 1580. 正答率(トレーニング) = 0.99
#                 : 1580. 正答率(テスト) = 0.9569
# Generation: 1590. 正答率(トレーニング) = 1.0
#                 : 1590. 正答率(テスト) = 0.9575
# Generation: 1600. 正答率(トレーニング) = 0.99
#                 : 1600. 正答率(テスト) = 0.9576
# Generation: 1610. 正答率(トレーニング) = 0.98
#                 : 1610. 正答率(テスト) = 0.9569
# Generation: 1620. 正答率(トレーニング) = 1.0
#                 : 1620. 正答率(テスト) = 0.9588
# Generation: 1630. 正答率(トレーニング) = 0.98
#                 : 1630. 正答率(テスト) = 0.9574
# Generation: 1640. 正答率(トレーニング) = 0.99
#                 : 1640. 正答率(テスト) = 0.9564
# Generation: 1650. 正答率(トレーニング) = 0.94
#                 : 1650. 正答率(テスト) = 0.9565
# Generation: 1660. 正答率(トレーニング) = 1.0
#                 : 1660. 正答率(テスト) = 0.9569
# Generation: 1670. 正答率(トレーニング) = 1.0
#                 : 1670. 正答率(テスト) = 0.9568
# Generation: 1680. 正答率(トレーニング) = 0.98
#                 : 1680. 正答率(テスト) = 0.9577
# Generation: 1690. 正答率(トレーニング) = 1.0
#                 : 1690. 正答率(テスト) = 0.961
# Generation: 1700. 正答率(トレーニング) = 0.99
#                 : 1700. 正答率(テスト) = 0.959
# Generation: 1710. 正答率(トレーニング) = 1.0
#                 : 1710. 正答率(テスト) = 0.9583
# Generation: 1720. 正答率(トレーニング) = 0.99
#                 : 1720. 正答率(テスト) = 0.9579
# Generation: 1730. 正答率(トレーニング) = 0.97
#                 : 1730. 正答率(テスト) = 0.9571
# Generation: 1740. 正答率(トレーニング) = 0.98
#                 : 1740. 正答率(テスト) = 0.9567
# Generation: 1750. 正答率(トレーニング) = 1.0
#                 : 1750. 正答率(テスト) = 0.9589
# Generation: 1760. 正答率(トレーニング) = 0.99
#                 : 1760. 正答率(テスト) = 0.9587
# Generation: 1770. 正答率(トレーニング) = 0.96
#                 : 1770. 正答率(テスト) = 0.9598
# Generation: 1780. 正答率(トレーニング) = 0.98
#                 : 1780. 正答率(テスト) = 0.9586
# Generation: 1790. 正答率(トレーニング) = 0.99
#                 : 1790. 正答率(テスト) = 0.9596
# Generation: 1800. 正答率(トレーニング) = 0.99
#                 : 1800. 正答率(テスト) = 0.9596
# Generation: 1810. 正答率(トレーニング) = 0.97
#                 : 1810. 正答率(テスト) = 0.9563
# Generation: 1820. 正答率(トレーニング) = 1.0
#                 : 1820. 正答率(テスト) = 0.9582
# Generation: 1830. 正答率(トレーニング) = 0.96
#                 : 1830. 正答率(テスト) = 0.957
# Generation: 1840. 正答率(トレーニング) = 0.98
#                 : 1840. 正答率(テスト) = 0.9566
# Generation: 1850. 正答率(トレーニング) = 0.97
#                 : 1850. 正答率(テスト) = 0.9587
# Generation: 1860. 正答率(トレーニング) = 0.97
#                 : 1860. 正答率(テスト) = 0.9609
# Generation: 1870. 正答率(トレーニング) = 1.0
#                 : 1870. 正答率(テスト) = 0.9602
# Generation: 1880. 正答率(トレーニング) = 0.98
#                 : 1880. 正答率(テスト) = 0.9543
# Generation: 1890. 正答率(トレーニング) = 0.97
#                 : 1890. 正答率(テスト) = 0.9606
# Generation: 1900. 正答率(トレーニング) = 0.98
#                 : 1900. 正答率(テスト) = 0.9586
# Generation: 1910. 正答率(トレーニング) = 0.97
#                 : 1910. 正答率(テスト) = 0.9577
# Generation: 1920. 正答率(トレーニング) = 0.98
#                 : 1920. 正答率(テスト) = 0.9579
# Generation: 1930. 正答率(トレーニング) = 0.98
#                 : 1930. 正答率(テスト) = 0.9588
# Generation: 1940. 正答率(トレーニング) = 0.97
#                 : 1940. 正答率(テスト) = 0.9626
# Generation: 1950. 正答率(トレーニング) = 0.99
#                 : 1950. 正答率(テスト) = 0.9606
# Generation: 1960. 正答率(トレーニング) = 1.0
#                 : 1960. 正答率(テスト) = 0.9565
# Generation: 1970. 正答率(トレーニング) = 1.0
#                 : 1970. 正答率(テスト) = 0.96
# Generation: 1980. 正答率(トレーニング) = 1.0
#                 : 1980. 正答率(テスト) = 0.9597
# Generation: 1990. 正答率(トレーニング) = 1.0
#                 : 1990. 正答率(テスト) = 0.9599
# Generation: 2000. 正答率(トレーニング) = 0.97
#                 : 2000. 正答率(テスト) = 0.9607

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] hidden_size_listの数字を変更してみよう

# %% [markdown]
# ## [try] sigmoid - He と relu - Xavier についても試してみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
